# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from utils import check_balance,visualize, creat_datasets, reset_graph, grid_serach, read_pick_file
from layers import  bln_layer, dense_layer
from callbacks import bln_callback , tensorboard_callback, create_callback_list, save_best_model_callback

# %%
tf.config.experimental_run_functions_eagerly(True)

# %%
tf.__version__
# Out:
# '2.1.0'

# %% [markdown]
# ### Loading data

# %%
random_seed = 100
minibatch = 20
buffersize = 60000
number_valid_sampels = 5000 # number of validation data
epochs = 5
learning_rate = 0.001
# 2250 -> 1 (all of the training dataset),  1125 -> .5 (half of the training dataset) , 562  -> .2 of the training dataset
number_batches_train = 2250 #number of batches to train, each batch of size minibatch parameter / 
number_batches_valid = 50 # number of batches to validate, each batch of size minibatch parameter
num_classes = 10

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
visualize(x_train)

# %%
train_dataset, valid_dataset, test_dataset = creat_datasets(x_train, y_train, x_test, y_test,
                                                            number_valid_sampels = number_valid_sampels,
                                                            random_seed = random_seed, minibatch = minibatch,
                                                            buffersize = buffersize, num_classes = num_classes,
                                                            reshape_to = 32*32*3, back_reshape = (-1,32,32,3))

# %% [markdown]
# #### Creating tf.data.Datasets

# %%
for i, j in valid_dataset.take(1) :
    print(i.shape, j.shape)
# Out:
# (20, 32, 32, 3) (20, 10)

# %% [markdown]
# # 1. Using Batch Layer Normalization Layer

# %%
def BLNLayer_model(inputshape= (32,32,3),
                    num_classes = 10, random_seed = 100,
                    batch_size = 60,
                    b_mm = True, b_mv = True,
                    f_mm = False, f_mv = False):
    
    # building the model
    
    input_lyr = tf.keras.Input(shape = inputshape, batch_size=batch_size, name = 'input')
    
      
    x = tf.keras.layers.Conv2D(filters=6, kernel_size=(5, 5), strides=(1, 1), activation='tanh', padding="same",
                               kernel_initializer=tf.keras.initializers.GlorotUniform(seed=random_seed)) (input_lyr)
    x = tf.keras.layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(x)
    x = bln_layer(stateful = True, batchsize= batch_size, name = 'bn1', 
                  batch_moving_mean = b_mm, batch_moving_var = b_mv,
                  feature_moving_mean = f_mm, feature_moving_var = f_mv)(x) 
    

    x = tf.keras.layers.Conv2D(filters=16, kernel_size=(5, 5), strides=(1, 1), activation='tanh', padding='valid',
                               kernel_initializer=tf.keras.initializers.GlorotUniform(seed=random_seed))(x)
    x = tf.keras.layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(x)
    x = bln_layer(stateful = True, batchsize= batch_size, name = 'bn2', 
                  batch_moving_mean = b_mm, batch_moving_var = b_mv,
                  feature_moving_mean = f_mm, feature_moving_var = f_mv)(x)
      
  
    # flattening the convolutions
    x = tf.keras.layers.Flatten()(x)
    
    # fully-connected layer
    x = dense_layer(units = 120, name = 'dense1', random_seed=random_seed)(x)
    x = tf.keras.layers.Activation('tanh')(x)
    x = bln_layer(stateful = True, batchsize= batch_size, name = 'bn3', 
                  batch_moving_mean = b_mm, batch_moving_var = b_mv,
                  feature_moving_mean = f_mm, feature_moving_var = f_mv)(x)
    
    x = dense_layer(units = 84, name = 'dense2', random_seed=random_seed)(x)
    x = tf.keras.layers.Activation('tanh')(x)
    x = bln_layer(stateful = True, batchsize= batch_size, name = 'bn4', 
                  batch_moving_mean = b_mm, batch_moving_var = b_mv,
                  feature_moving_mean = f_mm, feature_moving_var = f_mv)(x)
                                  
    output_lyr = dense_layer(units = num_classes, name = 'dense3', random_seed=random_seed)(x)
    
    return tf.keras.Model(inputs = [input_lyr], outputs = [output_lyr])

# %%
model_bln_layer = BLNLayer_model(inputshape = (32,32,3), 
                                 num_classes = num_classes,
                                 random_seed = random_seed,
                                 batch_size = minibatch,
                                 b_mm = True, b_mv = True,
                                 f_mm = False, f_mv = False,
                                )

# %%
model_bln_layer.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(20, 32, 32, 3)]         0
# _________________________________________________________________
# conv2d (Conv2D)              (20, 32, 32, 6)           456
# _________________________________________________________________
# average_pooling2d (AveragePo (20, 16, 16, 6)           0
# _________________________________________________________________
# bn1 (bln_layer)              (20, 16, 16, 6)           13326
# _________________________________________________________________
# conv2d_1 (Conv2D)            (20, 12, 12, 16)          2416
# _________________________________________________________________
# average_pooling2d_1 (Average (20, 6, 6, 16)            0
# _________________________________________________________________
# bn2 (bln_layer)              (20, 6, 6, 16)            2626
# _________________________________________________________________
# flatten (Flatten)            (20, 576)                 0
# _________________________________________________________________
# dense1 (dense_layer)         (20, 120)                 69240
# _________________________________________________________________
# activation (Activation)      (20, 120)                 0
# _________________________________________________________________
# bn3 (bln_layer)              (20, 120)                 522
# _________________________________________________________________
# dense2 (dense_layer)         (20, 84)                  10164
# _________________________________________________________________
# activation_1 (Activation)    (20, 84)                  0
# _________________________________________________________________
# bn4 (bln_layer)              (20, 84)                  378
# _________________________________________________________________
# dense3 (dense_layer)         (20, 10)                  850
# =================================================================
# Total params: 99,978
# Trainable params: 83,578
# Non-trainable params: 16,400
# _________________________________________________________________

# %% [markdown]
# # callbacks

# %%
# Callbacks for saving best model and tensorboard
folder_name = str(number_batches_train) + '_bln_layer_TTFF_cifar10'
save_bm_cb = save_best_model_callback(folder_name)
tb_cb = tensorboard_callback(folder_name)

# Callback for resetting moving mean and variances at the end of each epoch
bln_layer_cb = bln_callback()

bln_layer_cb_list = create_callback_list(save_bm_cb, tb_cb, bln_layer_cb)

# %%
model_bln_layer.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate),
                        loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                        metrics = [tf.keras.metrics.CategoricalAccuracy()])

# %%
model_bln_layer_history =  model_bln_layer.fit(train_dataset.take(number_batches_train), epochs = epochs,
                                                verbose = 1, callbacks = bln_layer_cb_list,
                                                validation_data = valid_dataset.take(number_batches_valid),
                                                shuffle = True)
# Out:
# Train for 2250 steps, validate for 50 steps
# Epoch 1/5
# 2250/2250 [==============================] - 101s 45ms/step - loss: 1.6573 - categorical_accuracy: 0.4103 - val_loss: 2.3496 - val_categorical_accuracy: 0.3010
# Epoch 2/5
# 2250/2250 [==============================] - 99s 44ms/step - loss: 1.3628 - categorical_accuracy: 0.5095 - val_loss: 1.3091 - val_categorical_accuracy: 0.5180
# Epoch 3/5
# 2250/2250 [==============================] - 103s 46ms/step - loss: 1.2303 - categorical_accuracy: 0.5626 - val_loss: 1.2481 - val_categorical_accuracy: 0.5370
# Epoch 4/5
# 2250/2250 [==============================] - 102s 45ms/step - loss: 1.1270 - categorical_accuracy: 0.6016 - val_loss: 1.2405 - val_categorical_accuracy: 0.5380
# Epoch 5/5
# 2250/2250 [==============================] - 103s 46ms/step - loss: 1.0435 - categorical_accuracy: 0.6328 - val_loss: 1.2647 - val_categorical_accuracy: 0.5380

# %%
weights_path = "./models/" + folder_name + '/'+ str(number_batches_train) +"_pretrained_weights_TTFF.h5"
model_bln_layer.save_weights(weights_path)

# %%
del model_bln_layer, save_bm_cb, tb_cb, bln_layer_cb, bln_layer_cb_list
reset_graph()
# Out:
# session is clear

# %%
save_eval_path = "./logs/" + folder_name + '/'+ str(number_batches_train) +"_sorted_evaluation.pkl"
evaluation = grid_serach(BLNLayer_model, test_dataset,
                         batch_size = minibatch, sort=True, 
                         save_eval_path = save_eval_path,
                         weights_path = weights_path)
# Out:
# 500/500 [==============================] - 8s 16ms/step - loss: 1.2927 - categorical_accuracy: 0.5538
# {'Bmm_True Bmv_True Fmm_True Fmv_True': [1.2926953198909759, 0.5538]}
# session is clear
# 500/500 [==============================] - 8s 15ms/step - loss: 1.2962 - categorical_accuracy: 0.5552
# {'Bmm_True Bmv_True Fmm_True Fmv_True': [1.2926953198909759, 0.5538], 'Bmm_True Bmv_True Fmm_True Fmv_False': [1.296248075723648, 0.5552]}
# session is clear
# 500/500 [==============================] - 8s 15ms/step - loss: 1.2928 - categorical_accuracy: 0.5549
# {'Bmm_True Bmv_True Fmm_True Fmv_True': [1.2926953198909759, 0.5538], 'Bmm_True Bmv_True Fmm_True Fmv_False': [1.296248075723648, 0.5552], 'Bmm_True Bmv_True Fmm_False Fmv_True': [1.2927826026082039, 0.5549]}
# session is clear
# 500/500 [==============================] - 8s 16ms/step - loss: 1.2926 - categorical_accuracy: 0.5553
# {'Bmm_True Bmv_True Fmm_True Fmv_True': [1.2926953198909759, 0.5538], 'Bmm_True Bmv_True Fmm_True Fmv_False': [1.296248075723648, 0.5552], 'Bmm_True Bmv_True Fmm_False Fmv_True': [1.2927826026082039, 0.5549], 'Bmm_True Bmv_True Fmm_False Fmv_False': [1.2926160812973977, 0.5553]}
# session is clear
# 500/500 [==============================] - 8s 16ms/step - loss: 1.4732 - categorical_accuracy: 0.5205
# {'Bmm_True Bmv_True Fmm_True Fmv_True': [1.2926953198909759, 0.5538], 'Bmm_True Bmv_True Fmm_True Fmv_False': [1.296248075723648, 0.5552], 'Bmm_True Bmv_True Fmm_False Fmv_True': [1.2927826026082039, 0.5549], 'Bmm_True Bmv_True Fmm_False Fmv_False': [1.2926160812973977, 0.5553], 'Bmm_True Bmv_False Fmm_True Fmv_True': [1.4732018792629242, 0.5205]}
# session is clear
# 500/500 [==============================] - 7s 15ms/step - loss: 1.4595 - categorical_accuracy: 0.5215
# {'Bmm_True Bmv_True Fmm_True Fmv_True': [1.2926953198909759, 0.5538], 'Bmm_True Bmv_True Fmm_True Fmv_False': [1.296248075723648, 0.5552], 'Bmm_True Bmv_True Fmm_False Fmv_True': [1.2927826026082039, 0.5549], 'Bmm_True Bmv_True Fmm_False Fmv_False': [1.2926160812973977, 0.5553], 'Bmm_True Bmv_False Fmm_True Fmv_True': [1.4732018792629242, 0.5205], 'Bmm_True Bmv_False Fmm_True Fmv_False': [1.4594527350068092, 0.5215]}
# session is clear
# 500/500 [==============================] - 8s 16ms/step - loss: 1.4955 - categorical_accuracy: 0.5166
# {'Bmm_True Bmv_True Fmm_True Fmv_True': [1.2926953198909759, 0.5538], 'Bmm_True Bmv_True Fmm_True Fmv_False': [1.296248075723648, 0.5552], 'Bmm_True Bmv_True Fmm_False Fmv_True': [1.2927826026082039, 0.5549], 'Bmm_True Bmv_True Fmm_False Fmv_False': [1.2926160812973977, 0.5553], 'Bmm_True Bmv_False Fmm_True Fmv_True': [1.4732018792629242, 0.5205], 'Bmm_True Bmv_False Fmm_True Fmv_False': [1.4594527350068092, 0.5215], 'Bmm_True Bmv_False Fmm_False Fmv_True': [1.4955497170090675, 0.5166]}
# session is clear
# 500/500 [==============================] - 8s 16ms/step - loss: 1.4966 - categorical_accuracy: 0.5162
# {'Bmm_True Bmv_True Fmm_True Fmv_True': [1.2926953198909759, 0.5538], 'Bmm_True Bmv_True Fmm_True Fmv_False': [1.296248075723648, 0.5552], 'Bmm_True Bmv_True Fmm_False Fmv_True': [1.2927826026082039, 0.5549], 'Bmm_True Bmv_True Fmm_False Fmv_False': [1.2926160812973977, 0.5553], 'Bmm_True Bmv_False Fmm_True Fmv_True': [1.4732018792629242, 0.5205], 'Bmm_True Bmv_False Fmm_True Fmv_False': [1.4594527350068092, 0.5215], 'Bmm_True Bmv_False Fmm_False Fmv_True': [1.4955497170090675, 0.5166], 'Bmm_True Bmv_False Fmm_False Fmv_False': [1.4965899724960328, 0.5162]}
# session is clear
# 500/500 [==============================] - 8s 16ms/step - loss: 1.2594 - categorical_accuracy: 0.5635
# {'Bmm_True Bmv_True Fmm_True Fmv_True': [1.2926953198909759, 0.5538], 'Bmm_True Bmv_True Fmm_True Fmv_False': [1.296248075723648, 0.5552], 'Bmm_True Bmv_True Fmm_False Fmv_True': [1.2927826026082039, 0.5549], 'Bmm_True Bmv_True Fmm_False Fmv_False': [1.2926160812973977, 0.5553], 'Bmm_True Bmv_False Fmm_True Fmv_True': [1.4732018792629242, 0.5205], 'Bmm_True Bmv_False Fmm_True Fmv_False': [1.4594527350068092, 0.5215], 'Bmm_True Bmv_False Fmm_False Fmv_True': [1.4955497170090675, 0.5166], 'Bmm_True Bmv_False Fmm_False Fmv_False': [1.4965899724960328, 0.5162], 'Bmm_False Bmv_True Fmm_True Fmv_True': [1.2594175740480422, 0.5635]}
# session is clear
# 500/500 [==============================] - 8s 17ms/step - loss: 1.2631 - categorical_accuracy: 0.5625
# {'Bmm_True Bmv_True Fmm_True Fmv_True': [1.2926953198909759, 0.5538], 'Bmm_True Bmv_True Fmm_True Fmv_False': [1.296248075723648, 0.5552], 'Bmm_True Bmv_True Fmm_False Fmv_True': [1.2927826026082039, 0.5549], 'Bmm_True Bmv_True Fmm_False Fmv_False': [1.2926160812973977, 0.5553], 'Bmm_True Bmv_False Fmm_True Fmv_True': [1.4732018792629242, 0.5205], 'Bmm_True Bmv_False Fmm_True Fmv_False': [1.4594527350068092, 0.5215], 'Bmm_True Bmv_False Fmm_False Fmv_True': [1.4955497170090675, 0.5166], 'Bmm_True Bmv_False Fmm_False Fmv_False': [1.4965899724960328, 0.5162], 'Bmm_False Bmv_True Fmm_True Fmv_True': [1.2594175740480422, 0.5635], 'Bmm_False Bmv_True Fmm_True Fmv_False': [1.2630532039403914, 0.5625]}
# session is clear
# 500/500 [==============================] - 9s 17ms/step - loss: 1.2574 - categorical_accuracy: 0.5625
# {'Bmm_True Bmv_True Fmm_True Fmv_True': [1.2926953198909759, 0.5538], 'Bmm_True Bmv_True Fmm_True Fmv_False': [1.296248075723648, 0.5552], 'Bmm_True Bmv_True Fmm_False Fmv_True': [1.2927826026082039, 0.5549], 'Bmm_True Bmv_True Fmm_False Fmv_False': [1.2926160812973977, 0.5553], 'Bmm_True Bmv_False Fmm_True Fmv_True': [1.4732018792629242, 0.5205], 'Bmm_True Bmv_False Fmm_True Fmv_False': [1.4594527350068092, 0.5215], 'Bmm_True Bmv_False Fmm_False Fmv_True': [1.4955497170090675, 0.5166], 'Bmm_True Bmv_False Fmm_False Fmv_False': [1.4965899724960328, 0.5162], 'Bmm_False Bmv_True Fmm_True Fmv_True': [1.2594175740480422, 0.5635], 'Bmm_False Bmv_True Fmm_True Fmv_False': [1.2630532039403914, 0.5625], 'Bmm_False Bmv_True Fmm_False Fmv_True': [1.2574110844135284, 0.5625]}
# session is clear
# 500/500 [==============================] - 8s 17ms/step - loss: 1.2581 - categorical_accuracy: 0.5622
# {'Bmm_True Bmv_True Fmm_True Fmv_True': [1.2926953198909759, 0.5538], 'Bmm_True Bmv_True Fmm_True Fmv_False': [1.296248075723648, 0.5552], 'Bmm_True Bmv_True Fmm_False Fmv_True': [1.2927826026082039, 0.5549], 'Bmm_True Bmv_True Fmm_False Fmv_False': [1.2926160812973977, 0.5553], 'Bmm_True Bmv_False Fmm_True Fmv_True': [1.4732018792629242, 0.5205], 'Bmm_True Bmv_False Fmm_True Fmv_False': [1.4594527350068092, 0.5215], 'Bmm_True Bmv_False Fmm_False Fmv_True': [1.4955497170090675, 0.5166], 'Bmm_True Bmv_False Fmm_False Fmv_False': [1.4965899724960328, 0.5162], 'Bmm_False Bmv_True Fmm_True Fmv_True': [1.2594175740480422, 0.5635], 'Bmm_False Bmv_True Fmm_True Fmv_False': [1.2630532039403914, 0.5625], 'Bmm_False Bmv_True Fmm_False Fmv_True': [1.2574110844135284, 0.5625], 'Bmm_False Bmv_True Fmm_False Fmv_False': [1.2581203685998916, 0.5622]}
# session is clear
# 500/500 [==============================] - 8s 16ms/step - loss: 1.2819 - categorical_accuracy: 0.5534
# {'Bmm_True Bmv_True Fmm_True Fmv_True': [1.2926953198909759, 0.5538], 'Bmm_True Bmv_True Fmm_True Fmv_False': [1.296248075723648, 0.5552], 'Bmm_True Bmv_True Fmm_False Fmv_True': [1.2927826026082039, 0.5549], 'Bmm_True Bmv_True Fmm_False Fmv_False': [1.2926160812973977, 0.5553], 'Bmm_True Bmv_False Fmm_True Fmv_True': [1.4732018792629242, 0.5205], 'Bmm_True Bmv_False Fmm_True Fmv_False': [1.4594527350068092, 0.5215], 'Bmm_True Bmv_False Fmm_False Fmv_True': [1.4955497170090675, 0.5166], 'Bmm_True Bmv_False Fmm_False Fmv_False': [1.4965899724960328, 0.5162], 'Bmm_False Bmv_True Fmm_True Fmv_True': [1.2594175740480422, 0.5635], 'Bmm_False Bmv_True Fmm_True Fmv_False': [1.2630532039403914, 0.5625], 'Bmm_False Bmv_True Fmm_False Fmv_True': [1.2574110844135284, 0.5625], 'Bmm_False Bmv_True Fmm_False Fmv_False': [1.2581203685998916, 0.5622], 'Bmm_False Bmv_False Fmm_True Fmv_True': [1.2819348912239075, 0.5534]}
# session is clear
# 500/500 [==============================] - 8s 16ms/step - loss: 1.2846 - categorical_accuracy: 0.5522
# {'Bmm_True Bmv_True Fmm_True Fmv_True': [1.2926953198909759, 0.5538], 'Bmm_True Bmv_True Fmm_True Fmv_False': [1.296248075723648, 0.5552], 'Bmm_True Bmv_True Fmm_False Fmv_True': [1.2927826026082039, 0.5549], 'Bmm_True Bmv_True Fmm_False Fmv_False': [1.2926160812973977, 0.5553], 'Bmm_True Bmv_False Fmm_True Fmv_True': [1.4732018792629242, 0.5205], 'Bmm_True Bmv_False Fmm_True Fmv_False': [1.4594527350068092, 0.5215], 'Bmm_True Bmv_False Fmm_False Fmv_True': [1.4955497170090675, 0.5166], 'Bmm_True Bmv_False Fmm_False Fmv_False': [1.4965899724960328, 0.5162], 'Bmm_False Bmv_True Fmm_True Fmv_True': [1.2594175740480422, 0.5635], 'Bmm_False Bmv_True Fmm_True Fmv_False': [1.2630532039403914, 0.5625], 'Bmm_False Bmv_True Fmm_False Fmv_True': [1.2574110844135284, 0.5625], 'Bmm_False Bmv_True Fmm_False Fmv_False': [1.2581203685998916, 0.5622], 'Bmm_False Bmv_False Fmm_True Fmv_True': [1.2819348912239075, 0.5534], 'Bmm_False Bmv_False Fmm_True Fmv_False': [1.2845814764499663, 0.5522]}
# session is clear
# 500/500 [==============================] - 9s 17ms/step - loss: 1.2811 - categorical_accuracy: 0.5538
# {'Bmm_True Bmv_True Fmm_True Fmv_True': [1.2926953198909759, 0.5538], 'Bmm_True Bmv_True Fmm_True Fmv_False': [1.296248075723648, 0.5552], 'Bmm_True Bmv_True Fmm_False Fmv_True': [1.2927826026082039, 0.5549], 'Bmm_True Bmv_True Fmm_False Fmv_False': [1.2926160812973977, 0.5553], 'Bmm_True Bmv_False Fmm_True Fmv_True': [1.4732018792629242, 0.5205], 'Bmm_True Bmv_False Fmm_True Fmv_False': [1.4594527350068092, 0.5215], 'Bmm_True Bmv_False Fmm_False Fmv_True': [1.4955497170090675, 0.5166], 'Bmm_True Bmv_False Fmm_False Fmv_False': [1.4965899724960328, 0.5162], 'Bmm_False Bmv_True Fmm_True Fmv_True': [1.2594175740480422, 0.5635], 'Bmm_False Bmv_True Fmm_True Fmv_False': [1.2630532039403914, 0.5625], 'Bmm_False Bmv_True Fmm_False Fmv_True': [1.2574110844135284, 0.5625], 'Bmm_False Bmv_True Fmm_False Fmv_False': [1.2581203685998916, 0.5622], 'Bmm_False Bmv_False Fmm_True Fmv_True': [1.2819348912239075, 0.5534], 'Bmm_False Bmv_False Fmm_True Fmv_False': [1.2845814764499663, 0.5522], 'Bmm_False Bmv_False Fmm_False Fmv_True': [1.281093763589859, 0.5538]}
# session is clear
# 500/500 [==============================] - 8s 15ms/step - loss: 1.2821 - categorical_accuracy: 0.5535
# {'Bmm_True Bmv_True Fmm_True Fmv_True': [1.2926953198909759, 0.5538], 'Bmm_True Bmv_True Fmm_True Fmv_False': [1.296248075723648, 0.5552], 'Bmm_True Bmv_True Fmm_False Fmv_True': [1.2927826026082039, 0.5549], 'Bmm_True Bmv_True Fmm_False Fmv_False': [1.2926160812973977, 0.5553], 'Bmm_True Bmv_False Fmm_True Fmv_True': [1.4732018792629242, 0.5205], 'Bmm_True Bmv_False Fmm_True Fmv_False': [1.4594527350068092, 0.5215], 'Bmm_True Bmv_False Fmm_False Fmv_True': [1.4955497170090675, 0.5166], 'Bmm_True Bmv_False Fmm_False Fmv_False': [1.4965899724960328, 0.5162], 'Bmm_False Bmv_True Fmm_True Fmv_True': [1.2594175740480422, 0.5635], 'Bmm_False Bmv_True Fmm_True Fmv_False': [1.2630532039403914, 0.5625], 'Bmm_False Bmv_True Fmm_False Fmv_True': [1.2574110844135284, 0.5625], 'Bmm_False Bmv_True Fmm_False Fmv_False': [1.2581203685998916, 0.5622], 'Bmm_False Bmv_False Fmm_True Fmv_True': [1.2819348912239075, 0.5534], 'Bmm_False Bmv_False Fmm_True Fmv_False': [1.2845814764499663, 0.5522], 'Bmm_False Bmv_False Fmm_False Fmv_True': [1.281093763589859, 0.5538], 'Bmm_False Bmv_False Fmm_False Fmv_False': [1.282140461087227, 0.5535]}
# session is clear

# %%
evaluation#
# Out:
# [('Bmm_False Bmv_True Fmm_False Fmv_True', [1.2574110844135284, 0.5625]),
#  ('Bmm_False Bmv_True Fmm_False Fmv_False', [1.2581203685998916, 0.5622]),
#  ('Bmm_False Bmv_True Fmm_True Fmv_True', [1.2594175740480422, 0.5635]),
#  ('Bmm_False Bmv_True Fmm_True Fmv_False', [1.2630532039403914, 0.5625]),
#  ('Bmm_False Bmv_False Fmm_False Fmv_True', [1.281093763589859, 0.5538]),
#  ('Bmm_False Bmv_False Fmm_True Fmv_True', [1.2819348912239075, 0.5534]),
#  ('Bmm_False Bmv_False Fmm_False Fmv_False', [1.282140461087227, 0.5535]),
#  ('Bmm_False Bmv_False Fmm_True Fmv_False', [1.2845814764499663, 0.5522]),
#  ('Bmm_True Bmv_True Fmm_False Fmv_False', [1.2926160812973977, 0.5553]),
#  ('Bmm_True Bmv_True Fmm_True Fmv_True', [1.2926953198909759, 0.5538]),
#  ('Bmm_True Bmv_True Fmm_False Fmv_True', [1.2927826026082039, 0.5549]),
#  ('Bmm_True Bmv_True Fmm_True Fmv_False', [1.296248075723648, 0.5552]),
#  ('Bmm_True Bmv_False Fmm_True Fmv_False', [1.4594527350068092, 0.5215]),
#  ('Bmm_True Bmv_False Fmm_True Fmv_True', [1.4732018792629242, 0.5205]),
#  ('Bmm_True Bmv_False Fmm_False Fmv_True', [1.4955497170090675, 0.5166]),
#  ('Bmm_True Bmv_False Fmm_False Fmv_False', [1.4965899724960328, 0.5162])]

# %% [markdown]
# # 2.Using  Batch Normalization implemented in Keras

# %%
def bn_keras_model(inputshape= (32,32,3), 
                    num_classes = 10,
                    random_seed = 100,
                    batch_size = 60):
    
    # building the model
    input_lyr = tf.keras.Input(shape = inputshape, batch_size=batch_size, name = 'input')
    
    x = tf.keras.layers.Conv2D(filters=6, kernel_size=(5, 5), strides=(1, 1), activation='tanh', padding="same",
                               kernel_initializer=tf.keras.initializers.GlorotUniform(seed=random_seed)) (input_lyr)
    x = tf.keras.layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(x)
    x = tf.keras.layers.BatchNormalization(momentum = 0.99, name = 'bn1')(x) 

    

    x = tf.keras.layers.Conv2D(filters=16, kernel_size=(5, 5), strides=(1, 1), activation='tanh', padding='valid',
                               kernel_initializer=tf.keras.initializers.GlorotUniform(seed=random_seed))(x)
    x = tf.keras.layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(x)
    x = tf.keras.layers.BatchNormalization(momentum = 0.99, name = 'bn2')(x) 

      
  
    # flattening the convolutions
    x = tf.keras.layers.Flatten()(x)
    
    # fully-connected layer
    x = dense_layer(units = 120, name = 'dense1', random_seed=random_seed)(x)
    x = tf.keras.layers.Activation('tanh')(x)
    x = tf.keras.layers.BatchNormalization(momentum = 0.99, name = 'bn3')(x) 

    
    x = dense_layer(units = 84, name = 'dense2', random_seed=random_seed)(x)
    x = tf.keras.layers.Activation('tanh')(x)
    x = tf.keras.layers.BatchNormalization(momentum = 0.99, name = 'bn4')(x) 

                                  
    output_lyr = dense_layer(units = num_classes, name = 'dense3', random_seed=random_seed)(x)
   
    
    return tf.keras.Model(inputs = [input_lyr], outputs = [output_lyr])

# %%
model_bn_keras = bn_keras_model(inputshape= (32,32,3), 
                                num_classes = 10, random_seed = 100,
                                batch_size = minibatch)
model_bn_keras.summary()

#### Compiling 
model_bn_keras.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate),
                     loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                     metrics = [tf.keras.metrics.CategoricalAccuracy()])
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(20, 32, 32, 3)]         0
# _________________________________________________________________
# conv2d (Conv2D)              (20, 32, 32, 6)           456
# _________________________________________________________________
# average_pooling2d (AveragePo (20, 16, 16, 6)           0
# _________________________________________________________________
# bn1 (BatchNormalization)     (20, 16, 16, 6)           24
# _________________________________________________________________
# conv2d_1 (Conv2D)            (20, 12, 12, 16)          2416
# _________________________________________________________________
# average_pooling2d_1 (Average (20, 6, 6, 16)            0
# _________________________________________________________________
# bn2 (BatchNormalization)     (20, 6, 6, 16)            64
# _________________________________________________________________
# flatten (Flatten)            (20, 576)                 0
# _________________________________________________________________
# dense1 (dense_layer)         (20, 120)                 69240
# _________________________________________________________________
# activation (Activation)      (20, 120)                 0
# _________________________________________________________________
# bn3 (BatchNormalization)     (20, 120)                 480
# _________________________________________________________________
# dense2 (dense_layer)         (20, 84)                  10164
# _________________________________________________________________
# activation_1 (Activation)    (20, 84)                  0
# _________________________________________________________________
# bn4 (BatchNormalization)     (20, 84)                  336
# _________________________________________________________________
# dense3 (dense_layer)         (20, 10)                  850
# =================================================================
# Total params: 84,030
# Trainable params: 83,578
# Non-trainable params: 452
# _________________________________________________________________

# %%
# Callbacks for saving best model and tensorboard
folder_name = str(number_batches_train) + '_bn_Keras_cifar10'
save_bm_cb = save_best_model_callback(folder_name)
tb_cb = tensorboard_callback(folder_name)

bn_keras_cb_list = [save_bm_cb, tb_cb]

# %%
model_bn_keras_history =  model_bn_keras.fit(train_dataset.take(number_batches_train),
                                             epochs=epochs, verbose=1, 
                                             callbacks=bn_keras_cb_list,
                                             validation_data=valid_dataset.take(number_batches_valid),
                                             shuffle=True)
# Out:
# Train for 2250 steps, validate for 50 steps
# Epoch 1/5
# 2250/2250 [==============================] - 63s 28ms/step - loss: 1.6773 - categorical_accuracy: 0.4070 - val_loss: 1.4129 - val_categorical_accuracy: 0.4930
# Epoch 2/5
# 2250/2250 [==============================] - 60s 27ms/step - loss: 1.3666 - categorical_accuracy: 0.5144 - val_loss: 1.2744 - val_categorical_accuracy: 0.5610
# Epoch 3/5
# 2250/2250 [==============================] - 62s 27ms/step - loss: 1.2280 - categorical_accuracy: 0.5670 - val_loss: 1.2393 - val_categorical_accuracy: 0.5760
# Epoch 4/5
# 2250/2250 [==============================] - 67s 30ms/step - loss: 1.1293 - categorical_accuracy: 0.6002 - val_loss: 1.2151 - val_categorical_accuracy: 0.5720
# Epoch 5/5
# 2250/2250 [==============================] - 75s 33ms/step - loss: 1.0444 - categorical_accuracy: 0.6336 - val_loss: 1.2158 - val_categorical_accuracy: 0.5610

# %%
model_bn_keras_test_history  = model_bn_keras.evaluate(test_dataset)
# Out:
# 500/500 [==============================] - 7s 13ms/step - loss: 1.2264 - categorical_accuracy: 0.5774

# %%
del model_bn_keras, save_bm_cb, tb_cb, bn_keras_cb_list 
reset_graph()
# Out:
# session is clear

# %% [markdown]
# # 3.Using  Layer normalization  implemented in Keras

# %%
def ln_keras_model(inputshape= (32,32,3), units1 = 512,
                    num_classes = 10, random_seed = 100,
                    batch_size = 60):
    
    # building the model
    
  # building the model
    input_lyr = tf.keras.Input(shape = inputshape, batch_size=batch_size, name = 'input')
    
    x = tf.keras.layers.Conv2D(filters=6, kernel_size=(5, 5), strides=(1, 1), activation='tanh', padding="same",
                               kernel_initializer=tf.keras.initializers.GlorotUniform(seed=random_seed)) (input_lyr)
    x = tf.keras.layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(x)
    x = tf.keras.layers.LayerNormalization()(x) 

    

    x = tf.keras.layers.Conv2D(filters=16, kernel_size=(5, 5), strides=(1, 1), activation='tanh', padding='valid',
                               kernel_initializer=tf.keras.initializers.GlorotUniform(seed=random_seed))(x)
    x = tf.keras.layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid')(x)
    x = tf.keras.layers.LayerNormalization()(x) 

      
  
    # flattening the convolutions
    x = tf.keras.layers.Flatten()(x)
    
    # fully-connected layer
    x = dense_layer(units = 120, name = 'dense1', random_seed=random_seed)(x)
    x = tf.keras.layers.Activation('tanh')(x)
    x = tf.keras.layers.LayerNormalization()(x) 

    
    x = dense_layer(units = 84, name = 'dense2', random_seed=random_seed)(x)
    x = tf.keras.layers.Activation('tanh')(x)
    x = tf.keras.layers.LayerNormalization()(x) 
                                  
    output_lyr = dense_layer(units = num_classes, name = 'dense3', random_seed=random_seed)(x)
   
    return tf.keras.Model(inputs = [input_lyr], outputs = [output_lyr])

# %%
model_ln_keras = ln_keras_model(inputshape= (32,32,3), 
                                num_classes = 10, random_seed = 100,
                                batch_size = minibatch)
model_ln_keras.summary()

#### Compiling 
model_ln_keras.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate),
                     loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                     metrics = [tf.keras.metrics.CategoricalAccuracy()])
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(20, 32, 32, 3)]         0
# _________________________________________________________________
# conv2d (Conv2D)              (20, 32, 32, 6)           456
# _________________________________________________________________
# average_pooling2d (AveragePo (20, 16, 16, 6)           0
# _________________________________________________________________
# layer_normalization (LayerNo (20, 16, 16, 6)           12
# _________________________________________________________________
# conv2d_1 (Conv2D)            (20, 12, 12, 16)          2416
# _________________________________________________________________
# average_pooling2d_1 (Average (20, 6, 6, 16)            0
# _________________________________________________________________
# layer_normalization_1 (Layer (20, 6, 6, 16)            32
# _________________________________________________________________
# flatten (Flatten)            (20, 576)                 0
# _________________________________________________________________
# dense1 (dense_layer)         (20, 120)                 69240
# _________________________________________________________________
# activation (Activation)      (20, 120)                 0
# _________________________________________________________________
# layer_normalization_2 (Layer (20, 120)                 240
# _________________________________________________________________
# dense2 (dense_layer)         (20, 84)                  10164
# _________________________________________________________________
# activation_1 (Activation)    (20, 84)                  0
# _________________________________________________________________
# layer_normalization_3 (Layer (20, 84)                  168
# _________________________________________________________________
# dense3 (dense_layer)         (20, 10)                  850
# =================================================================
# Total params: 83,578
# Trainable params: 83,578
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Callbacks for saving best model and tensorboard
folder_name = str(number_batches_train) + '_ln_Keras_cifar10'
save_bm_cb = save_best_model_callback(folder_name)
tb_cb = tensorboard_callback(folder_name)

ln_keras_cb_list = [save_bm_cb, tb_cb]

# %%
model_ln_keras_history =  model_ln_keras.fit(train_dataset.take(number_batches_train),
                                             epochs=epochs, verbose=1, 
                                             callbacks=ln_keras_cb_list,
                                             validation_data=valid_dataset.take(number_batches_valid),
                                             shuffle=True)
# Out:
# Train for 2250 steps, validate for 50 steps
# Epoch 1/5
# 2250/2250 [==============================] - 63s 28ms/step - loss: 1.6862 - categorical_accuracy: 0.4070 - val_loss: 1.4623 - val_categorical_accuracy: 0.4780
# Epoch 2/5
# 2250/2250 [==============================] - 64s 28ms/step - loss: 1.4385 - categorical_accuracy: 0.4896 - val_loss: 1.3641 - val_categorical_accuracy: 0.5210
# Epoch 3/5
# 2250/2250 [==============================] - 62s 28ms/step - loss: 1.3243 - categorical_accuracy: 0.5287 - val_loss: 1.3472 - val_categorical_accuracy: 0.5310
# Epoch 4/5
# 2250/2250 [==============================] - 65s 29ms/step - loss: 1.2307 - categorical_accuracy: 0.5606 - val_loss: 1.3361 - val_categorical_accuracy: 0.5280
# Epoch 5/5
# 2250/2250 [==============================] - 63s 28ms/step - loss: 1.1538 - categorical_accuracy: 0.5912 - val_loss: 1.2994 - val_categorical_accuracy: 0.5330

# %%
model_ln_keras_test_history = model_ln_keras.evaluate(test_dataset)
# Out:
# 500/500 [==============================] - 7s 14ms/step - loss: 1.3100 - categorical_accuracy: 0.5361

# %%
del model_ln_keras,save_bm_cb, ln_keras_cb_list
reset_graph()
# Out:
# session is clear

# %% [markdown]
# # 4. Make Comaprison between Layer Normalization, Batch Normalization and Batch Layer Normalization

# %%
# list all data in history
print(model_ln_keras_history.history.keys())
# summarize history for accuracy


plt.figsize=(12, 12)
plt.plot(model_ln_keras_history.history['loss'])
plt.plot(model_bn_keras_history.history['loss'])
plt.plot(model_bln_layer_history.history['loss'])
plt.scatter(4, model_ln_keras_test_history[0], s=80,  marker=(5, 2))
plt.scatter(4, model_bn_keras_test_history[0], s=80,  marker=(5, 2))
plt.scatter(4,evaluation[0][1][0], s=80,  marker=(5, 2))
plt.xticks(np.arange(0, 5, 1))

plt.title('model validation loss')
plt.ylabel('validation loss',fontsize=14)
plt.xlabel('epoch',fontsize=14)
plt.legend(['Layer Normalization', 'Batch Normalization','Batch Layer Normalization' ], loc='upper right')
ax = plt.gca()
ax.text(0.3,0.05,'Stars showing loss on test set',transform=ax.transAxes, bbox=dict(facecolor='none',edgecolor='black',boxstyle='square'))
plt.show()


plt.plot(model_ln_keras_history.history['categorical_accuracy'])
plt.plot(model_bn_keras_history.history['categorical_accuracy'])
plt.plot(model_bln_layer_history.history['categorical_accuracy'])
plt.scatter(4, model_ln_keras_test_history[1], s=80,  marker=(5, 2))
plt.scatter(4, model_bn_keras_test_history[1], s=80,  marker=(5, 2))
plt.scatter(4, evaluation[0][1][1], s=80,  marker=(5, 2))
plt.xticks(np.arange(0, 5, 1))
plt.yticks(np.arange(0.2, .6, .05))

plt.title('model validation accuracy')
plt.ylabel('validation accuracy', fontsize=14)
plt.xlabel('epoch',fontsize=14)
plt.legend(['Layer Normalization', 'Batch Normalization','Batch Layer Normalization' ], loc='upper left')
ax = plt.gca()
ax.text(0.3,0.05,'Stars showing accuracy on test set',transform=ax.transAxes, bbox=dict(facecolor='none',edgecolor='black',boxstyle='square'))
plt.show()
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy'])
